# %%
import pandas as pd
import numpy as np
import scipy.stats
import ratmetab
import itertools
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.colors as mcolors
import os

import warnings
warnings.filterwarnings('ignore')

# %%
data = ratmetab.read_all_data()

# %%
def insert_centered_LIscore(dataset, data=data):
    df = data[dataset]
    s = df.LIscore - df.LIscore.mean()
    val = pd.concat([pd.DataFrame({'LIscore cent.': s}, index=df.index), df], axis=1)
    return(val)

def insert_age(dataset, data=data):
    df = data[dataset]
    l = [(lambda g: 'Y' if g == 'Y' else 'A')(group) for group in df.Group]
    val = pd.concat([pd.DataFrame({'Age': l}, index=df.index), df], axis=1)
    return(val)

data = {dataset: insert_age(dataset, data=data) for dataset in data.keys()}
data = {dataset: insert_centered_LIscore(dataset, data=data) for dataset in data.keys()}

# %%
codebookpath = '../RatMetabolites/Rat_codebook_27_Oct_2022.csv'
codebook = pd.read_csv(codebookpath, index_col='MetaboliteName')
codebook['Metabolite'] = codebook.index
#codebook = ratmetab.add_subclassification_to_df(codebook, ratmetab.read_subclassification(), class_col='AnalyteClass')
codebook
# Out:
#                                               Assay  \
# MetaboliteName
# 22R-Hydroxycholesterol              Oxysterol assay
# 24S-Hydroxycholesterol              Oxysterol assay
# 24,25-Epoxycholesterol              Oxysterol assay
# 24,25-Dihydrolanosterol             Oxysterol assay
# 25-Hydroxycholesterol               Oxysterol assay
# 27-Hydroxycholesterol               Oxysterol assay
# 4-beta-Hydroxycholesterol           Oxysterol assay
# 5-alpha,6-alpha-Epoxycholesterol    Oxysterol assay
# 5-beta,6-beta-Epoxycholesterol      Oxysterol assay
# 7-Dehydrocholesterol                Oxysterol assay
# 7-Ketocholesterol                   Oxysterol assay
# 7-alpha-Hydroxycholesterol          Oxysterol assay
# 7-beta-Hydroxycholesterol           Oxysterol assay
# Acetylornithine                   AbsoluteIDQ® p180
# Asymmetric dimethylarginine       AbsoluteIDQ® p180
# Alanine                           AbsoluteIDQ® p180
# alpha-Aminoadipic acid            AbsoluteIDQ® p180
# Arginine                          AbsoluteIDQ® p180
# Asparagine                        AbsoluteIDQ® p180
# Aspartic Acid                     AbsoluteIDQ® p180
# Carnitine                         AbsoluteIDQ® p180
# Decanoylcarnitine                 AbsoluteIDQ® p180
# Decenoylcarnitine                 AbsoluteIDQ® p180
# Decadienoylcarnitine              AbsoluteIDQ® p180
# Dodecanoylcarnitine               AbsoluteIDQ® p180
# Dodecenoylcarnitine               AbsoluteIDQ® p180
# Dodecanedioylcarnitine            AbsoluteIDQ® p180
# Tetradecanoylcarnitine            AbsoluteIDQ® p180
# Tetradecenoylcarnitine            AbsoluteIDQ® p180
# Hydroxytetradecenoylcarnitine     AbsoluteIDQ® p180
# ...                                             ...
# Phosphatidylglycerol ae 34:0            Lipid assay
# Phosphatidylglycerol ae 34:1            Lipid assay
# Phosphatidylglycerol ae 36:1            Lipid assay
# Phosphatidylserine aa 34:1              Lipid assay
# Phosphatidylserine aa 34:2              Lipid assay
# Phosphatidylserine aa 36:0              Lipid assay
# Phosphatidylserine aa 36:1              Lipid assay
# Phosphatidylserine aa 36:2              Lipid assay
# Phosphatidylserine aa 36:3              Lipid assay
# Phosphatidylserine aa 36:4              Lipid assay
# Phosphatidylserine aa 38:1              Lipid assay
# Phosphatidylserine aa 38:2              Lipid assay
# Phosphatidylserine aa 38:3              Lipid assay
# Phosphatidylserine aa 38:4              Lipid assay
# Phosphatidylserine aa 38:5              Lipid assay
# Phosphatidylserine aa 40:1              Lipid assay
# Phosphatidylserine aa 40:2              Lipid assay
# Phosphatidylserine aa 40:3              Lipid assay
# Phosphatidylserine aa 40:4              Lipid assay
# Phosphatidylserine aa 40:5              Lipid assay
# Phosphatidylserine aa 40:6              Lipid assay
# Phosphatidylserine aa 40:7              Lipid assay
# Phosphatidylserine aa 42:1              Lipid assay
# Phosphatidylserine aa 42:2              Lipid assay
# Phosphatidylserine aa 42:4              Lipid assay
# Phosphatidylserine aa 42:5              Lipid assay
# Phosphatidylserine ae 34:2              Lipid assay
# Phosphatidylserine ae 36:1              Lipid assay
# Phosphatidylserine ae 36:2              Lipid assay
# Phosphatidylserine ae 38:4              Lipid assay
#
#                                                      AnalyteClass  \
# MetaboliteName
# 22R-Hydroxycholesterol                            Free_Oxysterols
# 24S-Hydroxycholesterol                            Free_Oxysterols
# 24,25-Epoxycholesterol                            Free_Oxysterols
# 24,25-Dihydrolanosterol                           Free_Oxysterols
# 25-Hydroxycholesterol                             Free_Oxysterols
# 27-Hydroxycholesterol                             Free_Oxysterols
# 4-beta-Hydroxycholesterol                         Free_Oxysterols
# 5-alpha,6-alpha-Epoxycholesterol                  Free_Oxysterols
# 5-beta,6-beta-Epoxycholesterol                    Free_Oxysterols
# 7-Dehydrocholesterol                              Free_Oxysterols
# 7-Ketocholesterol                                 Free_Oxysterols
# 7-alpha-Hydroxycholesterol                        Free_Oxysterols
# 7-beta-Hydroxycholesterol                         Free_Oxysterols
# Acetylornithine                   Amino_Acids_and_Biogenic_Amines
# Asymmetric dimethylarginine       Amino_Acids_and_Biogenic_Amines
# Alanine                           Amino_Acids_and_Biogenic_Amines
# alpha-Aminoadipic acid            Amino_Acids_and_Biogenic_Amines
# Arginine                          Amino_Acids_and_Biogenic_Amines
# Asparagine                        Amino_Acids_and_Biogenic_Amines
# Aspartic Acid                     Amino_Acids_and_Biogenic_Amines
# Carnitine                                          Acylcarnitines
# Decanoylcarnitine                                  Acylcarnitines
# Decenoylcarnitine                                  Acylcarnitines
# Decadienoylcarnitine                               Acylcarnitines
# Dodecanoylcarnitine                                Acylcarnitines
# Dodecenoylcarnitine                                Acylcarnitines
# Dodecanedioylcarnitine                             Acylcarnitines
# Tetradecanoylcarnitine                             Acylcarnitines
# Tetradecenoylcarnitine                             Acylcarnitines
# Hydroxytetradecenoylcarnitine                      Acylcarnitines
# ...                                                           ...
# Phosphatidylglycerol ae 34:0                Phosphatidylglycerols
# Phosphatidylglycerol ae 34:1                Phosphatidylglycerols
# Phosphatidylglycerol ae 36:1                Phosphatidylglycerols
# Phosphatidylserine aa 34:1                    Phosphatidylserines
# Phosphatidylserine aa 34:2                    Phosphatidylserines
# Phosphatidylserine aa 36:0                    Phosphatidylserines
# Phosphatidylserine aa 36:1                    Phosphatidylserines
# Phosphatidylserine aa 36:2                    Phosphatidylserines
# Phosphatidylserine aa 36:3                    Phosphatidylserines
# Phosphatidylserine aa 36:4                    Phosphatidylserines
# Phosphatidylserine aa 38:1                    Phosphatidylserines
# Phosphatidylserine aa 38:2                    Phosphatidylserines
# Phosphatidylserine aa 38:3                    Phosphatidylserines
# Phosphatidylserine aa 38:4                    Phosphatidylserines
# Phosphatidylserine aa 38:5                    Phosphatidylserines
# Phosphatidylserine aa 40:1                    Phosphatidylserines
# Phosphatidylserine aa 40:2                    Phosphatidylserines
# Phosphatidylserine aa 40:3                    Phosphatidylserines
# Phosphatidylserine aa 40:4                    Phosphatidylserines
# Phosphatidylserine aa 40:5                    Phosphatidylserines
# Phosphatidylserine aa 40:6                    Phosphatidylserines
# Phosphatidylserine aa 40:7                    Phosphatidylserines
# Phosphatidylserine aa 42:1                    Phosphatidylserines
# Phosphatidylserine aa 42:2                    Phosphatidylserines
# Phosphatidylserine aa 42:4                    Phosphatidylserines
# Phosphatidylserine aa 42:5                    Phosphatidylserines
# Phosphatidylserine ae 34:2                    Phosphatidylserines
# Phosphatidylserine ae 36:1                    Phosphatidylserines
# Phosphatidylserine ae 36:2                    Phosphatidylserines
# Phosphatidylserine ae 38:4                    Phosphatidylserines
#
#                                                                            HMDB_UID  \
# MetaboliteName
# 22R-Hydroxycholesterol                                                  HMDB0004035
# 24S-Hydroxycholesterol                                                    HMDB01419
# 24,25-Epoxycholesterol                                                          NaN
# 24,25-Dihydrolanosterol                                                 HMDB0006839
# 25-Hydroxycholesterol                                                     HMDB06247
# 27-Hydroxycholesterol                                                     HMDB02103
# 4-beta-Hydroxycholesterol                                               HMDB0013643
# 5-alpha,6-alpha-Epoxycholesterol                                                NaN
# 5-beta,6-beta-Epoxycholesterol                                                  NaN
# 7-Dehydrocholesterol                                                      HMDB00032
# 7-Ketocholesterol                                                         HMDB00501
# 7-alpha-Hydroxycholesterol                                                HMDB01496
# 7-beta-Hydroxycholesterol                                                 HMDB06119
# Acetylornithine                                                         HMDB0003357
# Asymmetric dimethylarginine                                               HMDB01539
# Alanine                                                        HMDB00161, HMDB01310
# alpha-Aminoadipic acid                                                    HMDB00510
# Arginine                                                       HMDB00517, HMDB03416
# Asparagine                                                   HMDB00168, HMDB0033780
# Aspartic Acid                                                  HMDB00191, HMDB06483
# Carnitine                                                                 HMDB00062
# Decanoylcarnitine                                                         HMDB00651
# Decenoylcarnitine                                                         HMDB13205
# Decadienoylcarnitine                                                    HMDB0013325
# Dodecanoylcarnitine                                                       HMDB02250
# Dodecenoylcarnitine                                                     HMDB0013326
# Dodecanedioylcarnitine                                                  HMDB0013327
# Tetradecanoylcarnitine                                                    HMDB05066
# Tetradecenoylcarnitine                                                  HMDB0002014
# Hydroxytetradecenoylcarnitine                                           HMDB0013330
# ...                                                                             ...
# Phosphatidylglycerol ae 34:0                                                    NaN
# Phosphatidylglycerol ae 34:1                                                    NaN
# Phosphatidylglycerol ae 36:1                                                    NaN
# Phosphatidylserine aa 34:1        HMDB0012357, HMDB0012387, HMDB0012367, HMDB001...
# Phosphatidylserine aa 34:2        HMDB0012368, HMDB0012388, HMDB0012398, HMDB001...
# Phosphatidylserine aa 36:0                                              HMDB0012378
# Phosphatidylserine aa 36:1                                     HMDB12389, HMDB10163
# Phosphatidylserine aa 36:2                                     HMDB12380, HMDB12390
# Phosphatidylserine aa 36:3        HMDB0012391, HMDB0012401, HMDB0012381, HMDB001...
# Phosphatidylserine aa 36:4                                     HMDB12402, HMDB12361
# Phosphatidylserine aa 38:1                                 HMDB0112375, HMDB0112350
# Phosphatidylserine aa 38:2                                 HMDB0112351, HMDB0112376
# Phosphatidylserine aa 38:3                                 HMDB0112377, HMDB0012382
# Phosphatidylserine aa 38:4                                   HMDB12383, HMDB0010165
# Phosphatidylserine aa 38:5        HMDB0012434, HMDB0012404, HMDB0012394, HMDB001...
# Phosphatidylserine aa 40:1        HMDB0112380, HMDB0112714, HMDB0112713, HMDB011...
# Phosphatidylserine aa 40:2        HMDB0112381, HMDB0112715, HMDB0112914, HMDB011...
# Phosphatidylserine aa 40:3        HMDB0112716, HMDB0112717, HMDB0112526, HMDB011...
# Phosphatidylserine aa 40:4                    HMDB0112382, HMDB0112528, HMDB0112529
# Phosphatidylserine aa 40:5                    HMDB0112383, HMDB0112530, HMDB0010166
# Phosphatidylserine aa 40:6                                                HMDB10167
# Phosphatidylserine aa 40:7                                                HMDB12395
# Phosphatidylserine aa 42:1        HMDB0112385, HMDB0112407, HMDB0112423, HMDB011...
# Phosphatidylserine aa 42:2        HMDB0112585, HMDB0112533, HMDB0112721, HMDB011...
# Phosphatidylserine aa 42:4        HMDB0112919, HMDB0112467, HMDB0112484, HMDB011...
# Phosphatidylserine aa 42:5        HMDB0112535, HMDB0112536, HMDB0112561, HMDB011...
# Phosphatidylserine ae 34:2                                                      NaN
# Phosphatidylserine ae 36:1                                                      NaN
# Phosphatidylserine ae 36:2                                                      NaN
# Phosphatidylserine ae 38:4                                                      NaN
#
#                                                                      CAS_UID  \
# MetaboliteName
# 22R-Hydroxycholesterol                                        CAS-17954-98-2
# 24S-Hydroxycholesterol                                          CAS-474-73-7
# 24,25-Epoxycholesterol                                        CAS-77058-74-3
# 24,25-Dihydrolanosterol                                          CAS-79-62-9
# 25-Hydroxycholesterol                                          CAS-2140-46-7
# 27-Hydroxycholesterol                         CAS-13095-61-9, CAS-20380-11-4
# 4-beta-Hydroxycholesterol                                     CAS-17320-10-4
# 5-alpha,6-alpha-Epoxycholesterol                               CAS-4025-59-6
# 5-beta,6-beta-Epoxycholesterol                                 CAS-4025-59-6
# 7-Dehydrocholesterol                                            CAS-434-16-2
# 7-Ketocholesterol                                               CAS-566-28-9
# 7-alpha-Hydroxycholesterol                                      CAS-566-26-7
# 7-beta-Hydroxycholesterol                                       CAS-566-27-8
# Acetylornithine                                 CAS-2185-16-2, CAS-6205-08-9
# Asymmetric dimethylarginine                   CAS-30315-93-6, CAS-30344-00-4
# Alanine                              CAS-56-41-7, CAS-302-72-7, CAS-338-69-2
# alpha-Aminoadipic acid            CAS-542-32-5, CAS-7620-28-2, CAS-1118-90-7
# Arginine                            CAS-74-79-3, CAS-7200-25-1, CAS-157-06-2
# Asparagine                        CAS-70-47-3 , CAS-3130-87-8, CAS-2058-58-4
# Aspartic Acid                       CAS-56-84-8, CAS-617-45-8, CAS-1783-96-6
# Carnitine                           CAS-541-15-1, CAS-541-14-0, CAS-461-06-3
# Decanoylcarnitine                                              CAS-1492-27-9
# Decenoylcarnitine                                           CAS-1256380-16-1
# Decadienoylcarnitine                                         CAS-128305-29-3
# Dodecanoylcarnitine                                           CAS-25518-54-1
# Dodecenoylcarnitine                                                      NaN
# Dodecanedioylcarnitine                                                   NaN
# Tetradecanoylcarnitine                                        CAS-25597-07-3
# Tetradecenoylcarnitine                                       CAS-835598-21-5
# Hydroxytetradecenoylcarnitine                                            NaN
# ...                                                                      ...
# Phosphatidylglycerol ae 34:0                                             NaN
# Phosphatidylglycerol ae 34:1                                             NaN
# Phosphatidylglycerol ae 36:1                                             NaN
# Phosphatidylserine aa 34:1                                    CAS-40290-44-6
# Phosphatidylserine aa 34:2                                               NaN
# Phosphatidylserine aa 36:0                                    CAS-51446-62-9
# Phosphatidylserine aa 36:1                                               NaN
# Phosphatidylserine aa 36:2                                    CAS-70614-14-1
# Phosphatidylserine aa 36:3                                               NaN
# Phosphatidylserine aa 36:4                                               NaN
# Phosphatidylserine aa 38:1                                               NaN
# Phosphatidylserine aa 38:2                                               NaN
# Phosphatidylserine aa 38:3                                               NaN
# Phosphatidylserine aa 38:4                                               NaN
# Phosphatidylserine aa 38:5                                               NaN
# Phosphatidylserine aa 40:1                                               NaN
# Phosphatidylserine aa 40:2                                               NaN
# Phosphatidylserine aa 40:3                                               NaN
# Phosphatidylserine aa 40:4                                               NaN
# Phosphatidylserine aa 40:5                                               NaN
# Phosphatidylserine aa 40:6                                               NaN
# Phosphatidylserine aa 40:7                                               NaN
# Phosphatidylserine aa 42:1                                               NaN
# Phosphatidylserine aa 42:2                                               NaN
# Phosphatidylserine aa 42:4                                               NaN
# Phosphatidylserine aa 42:5                                               NaN
# Phosphatidylserine ae 34:2                                               NaN
# Phosphatidylserine ae 36:1                                               NaN
# Phosphatidylserine ae 36:2                                               NaN
# Phosphatidylserine ae 38:4                                               NaN
#
#                                  UnitofConcentration metabolite  \
# MetaboliteName
# 22R-Hydroxycholesterol              [fmol/mg tissue]   _22R_OHC
# 24S-Hydroxycholesterol              [fmol/mg tissue]   _24S_OHC
# 24,25-Epoxycholesterol              [fmol/mg tissue]  _24_25_EC
# 24,25-Dihydrolanosterol             [fmol/mg tissue]  _24_DHLan
# 25-Hydroxycholesterol               [fmol/mg tissue]    _25_OHC
# 27-Hydroxycholesterol               [fmol/mg tissue]    _27_OHC
# 4-beta-Hydroxycholesterol           [fmol/mg tissue]    _4b_OHC
# 5-alpha,6-alpha-Epoxycholesterol    [fmol/mg tissue]   _5a6a_EC
# 5-beta,6-beta-Epoxycholesterol      [fmol/mg tissue]   _5b6b_EC
# 7-Dehydrocholesterol                [fmol/mg tissue]      _7_DC
# 7-Ketocholesterol                   [fmol/mg tissue]      _7_KC
# 7-alpha-Hydroxycholesterol          [fmol/mg tissue]    _7a_OHC
# 7-beta-Hydroxycholesterol           [fmol/mg tissue]    _7b_OHC
# Acetylornithine                     [pmol/mg tissue]      acorn
# Asymmetric dimethylarginine         [pmol/mg tissue]       adma
# Alanine                             [pmol/mg tissue]        ala
# alpha-Aminoadipic acid              [pmol/mg tissue]   alphaaaa
# Arginine                            [pmol/mg tissue]        arg
# Asparagine                          [pmol/mg tissue]        asn
# Aspartic Acid                       [pmol/mg tissue]        asp
# Carnitine                           [pmol/mg tissue]         c0
# Decanoylcarnitine                   [pmol/mg tissue]        c10
# Decenoylcarnitine                   [pmol/mg tissue]       c101
# Decadienoylcarnitine                [pmol/mg tissue]       c102
# Dodecanoylcarnitine                 [pmol/mg tissue]        c12
# Dodecenoylcarnitine                 [pmol/mg tissue]       c121
# Dodecanedioylcarnitine              [pmol/mg tissue]      c12dc
# Tetradecanoylcarnitine              [pmol/mg tissue]        c14
# Tetradecenoylcarnitine              [pmol/mg tissue]       c141
# Hydroxytetradecenoylcarnitine       [pmol/mg tissue]     c141oh
# ...                                              ...        ...
# Phosphatidylglycerol ae 34:0        [pmol/mg tissue]   pgaec340
# Phosphatidylglycerol ae 34:1        [pmol/mg tissue]   pgaec341
# Phosphatidylglycerol ae 36:1        [pmol/mg tissue]   pgaec361
# Phosphatidylserine aa 34:1          [pmol/mg tissue]   psaac341
# Phosphatidylserine aa 34:2          [pmol/mg tissue]   psaac342
# Phosphatidylserine aa 36:0          [pmol/mg tissue]   psaac360
# Phosphatidylserine aa 36:1          [pmol/mg tissue]   psaac361
# Phosphatidylserine aa 36:2          [pmol/mg tissue]   psaac362
# Phosphatidylserine aa 36:3          [pmol/mg tissue]   psaac363
# Phosphatidylserine aa 36:4          [pmol/mg tissue]   psaac364
# Phosphatidylserine aa 38:1          [pmol/mg tissue]   psaac381
# Phosphatidylserine aa 38:2          [pmol/mg tissue]   psaac382
# Phosphatidylserine aa 38:3          [pmol/mg tissue]   psaac383
# Phosphatidylserine aa 38:4          [pmol/mg tissue]   psaac384
# Phosphatidylserine aa 38:5          [pmol/mg tissue]   psaac385
# Phosphatidylserine aa 40:1          [pmol/mg tissue]   psaac401
# Phosphatidylserine aa 40:2          [pmol/mg tissue]   psaac402
# Phosphatidylserine aa 40:3          [pmol/mg tissue]   psaac403
# Phosphatidylserine aa 40:4          [pmol/mg tissue]   psaac404
# Phosphatidylserine aa 40:5          [pmol/mg tissue]   psaac405
# Phosphatidylserine aa 40:6          [pmol/mg tissue]   psaac406
# Phosphatidylserine aa 40:7          [pmol/mg tissue]   psaac407
# Phosphatidylserine aa 42:1          [pmol/mg tissue]   psaac421
# Phosphatidylserine aa 42:2          [pmol/mg tissue]   psaac422
# Phosphatidylserine aa 42:4          [pmol/mg tissue]   psaac424
# Phosphatidylserine aa 42:5          [pmol/mg tissue]   psaac425
# Phosphatidylserine ae 34:2          [pmol/mg tissue]   psaec342
# Phosphatidylserine ae 36:1          [pmol/mg tissue]   psaec361
# Phosphatidylserine ae 36:2          [pmol/mg tissue]   psaec362
# Phosphatidylserine ae 38:4          [pmol/mg tissue]   psaec384
#
#                                                         Metabolite
# MetaboliteName
# 22R-Hydroxycholesterol                      22R-Hydroxycholesterol
# 24S-Hydroxycholesterol                      24S-Hydroxycholesterol
# 24,25-Epoxycholesterol                      24,25-Epoxycholesterol
# 24,25-Dihydrolanosterol                    24,25-Dihydrolanosterol
# 25-Hydroxycholesterol                        25-Hydroxycholesterol
# 27-Hydroxycholesterol                        27-Hydroxycholesterol
# 4-beta-Hydroxycholesterol                4-beta-Hydroxycholesterol
# 5-alpha,6-alpha-Epoxycholesterol  5-alpha,6-alpha-Epoxycholesterol
# 5-beta,6-beta-Epoxycholesterol      5-beta,6-beta-Epoxycholesterol
# 7-Dehydrocholesterol                          7-Dehydrocholesterol
# 7-Ketocholesterol                                7-Ketocholesterol
# 7-alpha-Hydroxycholesterol              7-alpha-Hydroxycholesterol
# 7-beta-Hydroxycholesterol                7-beta-Hydroxycholesterol
# Acetylornithine                                    Acetylornithine
# Asymmetric dimethylarginine            Asymmetric dimethylarginine
# Alanine                                                    Alanine
# alpha-Aminoadipic acid                      alpha-Aminoadipic acid
# Arginine                                                  Arginine
# Asparagine                                              Asparagine
# Aspartic Acid                                        Aspartic Acid
# Carnitine                                                Carnitine
# Decanoylcarnitine                                Decanoylcarnitine
# Decenoylcarnitine                                Decenoylcarnitine
# Decadienoylcarnitine                          Decadienoylcarnitine
# Dodecanoylcarnitine                            Dodecanoylcarnitine
# Dodecenoylcarnitine                            Dodecenoylcarnitine
# Dodecanedioylcarnitine                      Dodecanedioylcarnitine
# Tetradecanoylcarnitine                      Tetradecanoylcarnitine
# Tetradecenoylcarnitine                      Tetradecenoylcarnitine
# Hydroxytetradecenoylcarnitine        Hydroxytetradecenoylcarnitine
# ...                                                            ...
# Phosphatidylglycerol ae 34:0          Phosphatidylglycerol ae 34:0
# Phosphatidylglycerol ae 34:1          Phosphatidylglycerol ae 34:1
# Phosphatidylglycerol ae 36:1          Phosphatidylglycerol ae 36:1
# Phosphatidylserine aa 34:1              Phosphatidylserine aa 34:1
# Phosphatidylserine aa 34:2              Phosphatidylserine aa 34:2
# Phosphatidylserine aa 36:0              Phosphatidylserine aa 36:0
# Phosphatidylserine aa 36:1              Phosphatidylserine aa 36:1
# Phosphatidylserine aa 36:2              Phosphatidylserine aa 36:2
# Phosphatidylserine aa 36:3              Phosphatidylserine aa 36:3
# Phosphatidylserine aa 36:4              Phosphatidylserine aa 36:4
# Phosphatidylserine aa 38:1              Phosphatidylserine aa 38:1
# Phosphatidylserine aa 38:2              Phosphatidylserine aa 38:2
# Phosphatidylserine aa 38:3              Phosphatidylserine aa 38:3
# Phosphatidylserine aa 38:4              Phosphatidylserine aa 38:4
# Phosphatidylserine aa 38:5              Phosphatidylserine aa 38:5
# Phosphatidylserine aa 40:1              Phosphatidylserine aa 40:1
# Phosphatidylserine aa 40:2              Phosphatidylserine aa 40:2
# Phosphatidylserine aa 40:3              Phosphatidylserine aa 40:3
# Phosphatidylserine aa 40:4              Phosphatidylserine aa 40:4
# Phosphatidylserine aa 40:5              Phosphatidylserine aa 40:5
# Phosphatidylserine aa 40:6              Phosphatidylserine aa 40:6
# Phosphatidylserine aa 40:7              Phosphatidylserine aa 40:7
# Phosphatidylserine aa 42:1              Phosphatidylserine aa 42:1
# Phosphatidylserine aa 42:2              Phosphatidylserine aa 42:2
# Phosphatidylserine aa 42:4              Phosphatidylserine aa 42:4
# Phosphatidylserine aa 42:5              Phosphatidylserine aa 42:5
# Phosphatidylserine ae 34:2              Phosphatidylserine ae 34:2
# Phosphatidylserine ae 36:1              Phosphatidylserine ae 36:1
# Phosphatidylserine ae 36:2              Phosphatidylserine ae 36:2
# Phosphatidylserine ae 38:4              Phosphatidylserine ae 38:4
#
# [499 rows x 7 columns]

# %%
""""codebookpath = '../RatMetabolites/Rat_codebook_27_Oct_2022.csv'
datapath = {
    'blood new': 'blood_27_Oct_2022',
    'brain new': 'brain_27_Oct_2022',
    'blood old': 'old_blood_17_Nov_2022',
    'brain old': 'old_brain_17_Nov_2022',
               }
data = {k: ratmetab.read_data('../RatMetabolites/Rat_' + v + '.csv', codebookpath, liberal_filter=True) for k, v in datapath.items()}

data.update({tissue: pd.concat([data[tissue + ' new'], data[tissue + ' old']], axis=0, join='outer') for tissue in ['blood', 'brain']})

def insert_centered_LIscore(dataset, data=data):
    df = data[dataset]
    s = df.LIscore - df.LIscore.mean()
    val = pd.concat([pd.DataFrame({'LIscore cent.': s}, index=df.index), df], axis=1)
    return(val)

def insert_age(dataset, data=data):
    df = data[dataset]
    l = [(lambda g: 'Y' if g == 'Y' else 'A')(group) for group in df.Group]
    val = pd.concat([pd.DataFrame({'Age': l}, index=df.index), df], axis=1)
    return(val)

data = {dataset: insert_age(dataset, data=data) for dataset in data.keys()}
data = {dataset: insert_centered_LIscore(dataset, data=data) for dataset in data.keys()}"""
# Out:
# '"codebookpath = \'../RatMetabolites/Rat_codebook_27_Oct_2022.csv\'\ndatapath = {\n    \'blood new\': \'blood_27_Oct_2022\',\n    \'brain new\': \'brain_27_Oct_2022\',\n    \'blood old\': \'old_blood_17_Nov_2022\',\n    \'brain old\': \'old_brain_17_Nov_2022\',\n               }\ndata = {k: ratmetab.read_data(\'../RatMetabolites/Rat_\' + v + \'.csv\', codebookpath, liberal_filter=True) for k, v in datapath.items()}\n\ndata.update({tissue: pd.concat([data[tissue + \' new\'], data[tissue + \' old\']], axis=0, join=\'outer\') for tissue in [\'blood\', \'brain\']})\n\ndef insert_centered_LIscore(dataset, data=data):\n    df = data[dataset]\n    s = df.LIscore - df.LIscore.mean()\n    val = pd.concat([pd.DataFrame({\'LIscore cent.\': s}, index=df.index), df], axis=1)\n    return(val)\n\ndef insert_age(dataset, data=data):\n    df = data[dataset]\n    l = [(lambda g: \'Y\' if g == \'Y\' else \'A\')(group) for group in df.Group]\n    val = pd.concat([pd.DataFrame({\'Age\': l}, index=df.index), df], axis=1)\n    return(val)\n\ndata = {dataset: insert_age(dataset, data=data) for dataset in data.keys()}\ndata = {dataset: insert_centered_LIscore(dataset, data=data) for dataset in data.keys()}'

# %%
#codebook = pd.read_csv(codebookpath, index_col='MetaboliteName')

# %%
def scipy_transfor_helper(s, fun=scipy.stats.boxcox):
    try:
        val = fun(s)[0]
    except(ValueError):
        val = s.apply(lambda x: np.nan)
    res = pd.Series(val, index=s.index)
    return(res)

def myboxcox(s): return(scipy_transfor_helper(s, scipy.stats.boxcox))
def myyeojohnson(s): return(scipy_transfor_helper(s, scipy.stats.yeojohnson))

def transform_data(aclass, transformation=np.log, dat=data['blood'], codebook=codebook, class_col='AnalyteClass'):
    aclass_metabolites = codebook.loc[codebook[class_col] == aclass].index
    sel_metabolites = list(set(dat.columns).intersection(set(aclass_metabolites)))
    sel_cols = ['LIscore cent.', 'Age'] + sel_metabolites
    df = dat.loc[:, sel_metabolites]
    df = df.apply(transformation, axis=1)
    # standardization
    df = df.apply(lambda x: (x - df.mean(axis=0)) / df.std(axis=0), axis=1)
    return(df)

transformations = {
    'no': lambda x: x,
    'log': np.log,
    'Box-Cox': myboxcox,
    'Yeo-Johnson': myyeojohnson,
}

def distplot_aclass(aclass, transformations=transformations, dat=data['blood'], codebook=codebook, class_col='AnalyteClass'):
    ntrans = len(transformations)
    fig, ax = plt.subplots(1, ntrans, figsize=(4 * ntrans, 4))
    std_trans_dfs = {name: transform_data(aclass, transformation=trans, dat=dat, codebook=codebook, class_col=class_col) for name, trans in transformations.items()}
    df0 = std_trans_dfs[list(transformations.keys())[0]]
    stepsize = np.int64(np.floor(len(mcolors.CSS4_COLORS) / df0.shape[1]))
    colors = list(mcolors.CSS4_COLORS.values())[::stepsize]
    for metabolite, color in zip(df0, colors):
        for i, items in enumerate(zip(ax, std_trans_dfs.keys(), std_trans_dfs.values())):
            axi, name, tdf = items
            label = metabolite if i == 0 else None
            sm.qqplot(tdf[metabolite], label=label, ax=axi, linewidth=1, linestyle='solid', color=color, markerfacecolor=color, marker='.', line='45')
            axi.set_title(name + ' transformation')
            axi.set_xlabel('')
            axi.set_ylabel('')
    fig.legend(ncol=ntrans, loc='upper center', bbox_to_anchor=(0.5, 0), title=aclass + ' in data set')
    fig.suptitle(aclass + ': normal QQ plots')
    #fig.supxlabel('Theoretical quantiles')
    #fig.supylabel('Sample quantiles')
    return((fig, ax))

# %%
class_col = 'AnalyteClass'
subclasses = list(np.unique(codebook[class_col]))
print(subclasses)
subclasses.remove('Acylcarnitines')
subclasses.remove('Amino_Acids_and_Biogenic_Amines')
subclasses.remove('Ceramides')
subclasses.remove('Free_Fatty_Acids')
subclasses.remove('Hexoses')
subclasses.remove('Lysophosphatidylcholines')
subclasses.remove('Phosphatidylcholines')
subclasses.remove('Phosphatidylethanolamines')
subclasses.remove('Phosphatidylglycerols')
subclasses.remove('Phosphatidylserines')
subclasses.remove('Sphingomyelins')
for aclass in subclasses:
    fig, ax = distplot_aclass(aclass, dat=data['blood'], codebook=codebook, class_col=class_col)
# Out:
# ['Acylcarnitines', 'Amino_Acids_and_Biogenic_Amines', 'Bile_Acids', 'Ceramides', 'Free_Fatty_Acids', 'Free_Oxysterols', 'Hexoses', 'Lysophosphatidylcholines', 'Phosphatidylcholines', 'Phosphatidylethanolamines', 'Phosphatidylglycerols', 'Phosphatidylserines', 'Sphingomyelins']

# %%
fm4 = 'Level ~ C(Age, levels=["Y", "A"]) + Age : Q("LIscore cent.")'
fm5 = 'Level ~ C(Age, levels=["Y", "A"]) * Q("LIscore cent.")'

def fit_aclass_data(aclass, formula, transformation=transformations['no'], dat=data['blood'], codebook=codebook, class_col='AnalyteClass'):
    df = transform_data(aclass, transformation=transformation, dat=dat, codebook=codebook, class_col=class_col)
    sel_metabolites = df.columns
    df = df.stack(dropna=False).to_frame('Level')
    df['Age'] = np.repeat(dat.Age, len(sel_metabolites)).to_list()
    df['LIscore cent.'] = np.repeat(dat['LIscore cent.'], len(sel_metabolites)).to_list()
    df['Metabolite'] = df.index.get_level_values(1)
    df = df.dropna()
    fmod = smf.mixedlm(formula, data=df, groups='Metabolite').fit()
    return(fmod)

def extract_fit_info(fmod, aclass, transformation_name):
    fmod.summary()
    d = {'Estimate': fmod.params, 'SE': fmod.bse, 'p': fmod.pvalues}
    ll = [a.to_list() for a in d.values()]
    l = itertools.chain(*ll)
    ix = pd.MultiIndex.from_product([d.keys(), d['Estimate'].index])
    df = pd.DataFrame({aclass: l}, index=ix).transpose()
    df[('General', 'Converged')] = fmod.converged
    df[('General', 'Fitted model')] = fmod
    df[('General', 'Transformation')] = transformation_name
    return(df)

def process_aclass(aclass, formula, transformation_name='no', dat=data['blood'], codebook=codebook, class_col='AnalyteClass'):
    transformation = transformations[transformation_name]
    fmod = fit_aclass_data(aclass, formula, transformation=transformation, dat=dat, codebook=codebook, class_col=class_col)
    df = extract_fit_info(fmod, aclass, transformation_name)
    return(df)

# %%
class_col = 'AnalyteClass'
l = [process_aclass(aclass, fm4, transformation_name='no', class_col=class_col) for aclass in np.unique(codebook[class_col])]
results_m4 = pd.concat(l, axis=0)

# %%
class_col = 'AnalyteClass'
l = [process_aclass(aclass, fm4, transformation_name='log', class_col=class_col) for aclass in np.unique(codebook[class_col])]
results_m4_log = pd.concat(l, axis=0)

# %%
results_m4
# Out:
#                                                                 Estimate  \
#                                                                Intercept
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                           C(Age, levels=["Y", "A"])[T.A]
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                Age[A]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                Age[Y]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                           Metabolite Var
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                       SE  \
#                                                                Intercept
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                           C(Age, levels=["Y", "A"])[T.A]
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                Age[A]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                Age[Y]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                           Metabolite Var
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                        p  \
#                                                                Intercept
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                           C(Age, levels=["Y", "A"])[T.A]
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                Age[A]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                Age[Y]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                                                           \
#                                                           Metabolite Var
# Acylcarnitines                   <itertools.chain object at 0x123528748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x1238c0048>
# Bile_Acids                       <itertools.chain object at 0x1225ea0f0>
# Ceramides                        <itertools.chain object at 0x1225ea0b8>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ee487b8>
# Free_Oxysterols                  <itertools.chain object at 0x1244fe390>
# Hexoses                          <itertools.chain object at 0x124816da0>
# Lysophosphatidylcholines         <itertools.chain object at 0x1231824a8>
# Phosphatidylcholines             <itertools.chain object at 0x123182fd0>
# Phosphatidylethanolamines        <itertools.chain object at 0x1221a1208>
# Phosphatidylglycerols            <itertools.chain object at 0x122512a90>
# Phosphatidylserines              <itertools.chain object at 0x122512908>
# Sphingomyelins                   <itertools.chain object at 0x11ff5c7f0>
#
#                                   General  \
#                                 Converged
# Acylcarnitines                       True
# Amino_Acids_and_Biogenic_Amines      True
# Bile_Acids                          False
# Ceramides                            True
# Free_Fatty_Acids                     True
# Free_Oxysterols                     False
# Hexoses                              True
# Lysophosphatidylcholines             True
# Phosphatidylcholines                False
# Phosphatidylethanolamines            True
# Phosphatidylglycerols               False
# Phosphatidylserines                 False
# Sphingomyelins                       True
#
#                                                                                     \
#                                                                       Fitted model
# Acylcarnitines                   <statsmodels.regression.mixed_linear_model.Mix...
# Amino_Acids_and_Biogenic_Amines  <statsmodels.regression.mixed_linear_model.Mix...
# Bile_Acids                       <statsmodels.regression.mixed_linear_model.Mix...
# Ceramides                        <statsmodels.regression.mixed_linear_model.Mix...
# Free_Fatty_Acids                 <statsmodels.regression.mixed_linear_model.Mix...
# Free_Oxysterols                  <statsmodels.regression.mixed_linear_model.Mix...
# Hexoses                          <statsmodels.regression.mixed_linear_model.Mix...
# Lysophosphatidylcholines         <statsmodels.regression.mixed_linear_model.Mix...
# Phosphatidylcholines             <statsmodels.regression.mixed_linear_model.Mix...
# Phosphatidylethanolamines        <statsmodels.regression.mixed_linear_model.Mix...
# Phosphatidylglycerols            <statsmodels.regression.mixed_linear_model.Mix...
# Phosphatidylserines              <statsmodels.regression.mixed_linear_model.Mix...
# Sphingomyelins                   <statsmodels.regression.mixed_linear_model.Mix...
#
#
#                                 Transformation
# Acylcarnitines                              no
# Amino_Acids_and_Biogenic_Amines             no
# Bile_Acids                                  no
# Ceramides                                   no
# Free_Fatty_Acids                            no
# Free_Oxysterols                             no
# Hexoses                                     no
# Lysophosphatidylcholines                    no
# Phosphatidylcholines                        no
# Phosphatidylethanolamines                   no
# Phosphatidylglycerols                       no
# Phosphatidylserines                         no
# Sphingomyelins                              no

# %%
results_m4_log
# Out:
#                                                                 Estimate  \
#                                                                Intercept
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                           C(Age, levels=["Y", "A"])[T.A]
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                Age[A]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                Age[Y]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                           Metabolite Var
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                       SE  \
#                                                                Intercept
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                           C(Age, levels=["Y", "A"])[T.A]
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                Age[A]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                Age[Y]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                           Metabolite Var
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                        p  \
#                                                                Intercept
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                           C(Age, levels=["Y", "A"])[T.A]
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                Age[A]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                Age[Y]:Q("LIscore cent.")
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                                                           \
#                                                           Metabolite Var
# Acylcarnitines                   <itertools.chain object at 0x12270d748>
# Amino_Acids_and_Biogenic_Amines  <itertools.chain object at 0x12330a3c8>
# Bile_Acids                       <itertools.chain object at 0x1222e4ba8>
# Ceramides                        <itertools.chain object at 0x11e9134e0>
# Free_Fatty_Acids                 <itertools.chain object at 0x11ff6c208>
# Free_Oxysterols                  <itertools.chain object at 0x123f8f9b0>
# Hexoses                          <itertools.chain object at 0x1223e5550>
# Lysophosphatidylcholines         <itertools.chain object at 0x124a072e8>
# Phosphatidylcholines             <itertools.chain object at 0x11e987438>
# Phosphatidylethanolamines        <itertools.chain object at 0x11e987208>
# Phosphatidylglycerols            <itertools.chain object at 0x12142ca20>
# Phosphatidylserines              <itertools.chain object at 0x11e99e588>
# Sphingomyelins                   <itertools.chain object at 0x11f1df6d8>
#
#                                   General  \
#                                 Converged
# Acylcarnitines                       True
# Amino_Acids_and_Biogenic_Amines      True
# Bile_Acids                          False
# Ceramides                           False
# Free_Fatty_Acids                     True
# Free_Oxysterols                      True
# Hexoses                              True
# Lysophosphatidylcholines             True
# Phosphatidylcholines                False
# Phosphatidylethanolamines            True
# Phosphatidylglycerols               False
# Phosphatidylserines                 False
# Sphingomyelins                      False
#
#                                                                                     \
#                                                                       Fitted model
# Acylcarnitines                   <statsmodels.regression.mixed_linear_model.Mix...
# Amino_Acids_and_Biogenic_Amines  <statsmodels.regression.mixed_linear_model.Mix...
# Bile_Acids                       <statsmodels.regression.mixed_linear_model.Mix...
# Ceramides                        <statsmodels.regression.mixed_linear_model.Mix...
# Free_Fatty_Acids                 <statsmodels.regression.mixed_linear_model.Mix...
# Free_Oxysterols                  <statsmodels.regression.mixed_linear_model.Mix...
# Hexoses                          <statsmodels.regression.mixed_linear_model.Mix...
# Lysophosphatidylcholines         <statsmodels.regression.mixed_linear_model.Mix...
# Phosphatidylcholines             <statsmodels.regression.mixed_linear_model.Mix...
# Phosphatidylethanolamines        <statsmodels.regression.mixed_linear_model.Mix...
# Phosphatidylglycerols            <statsmodels.regression.mixed_linear_model.Mix...
# Phosphatidylserines              <statsmodels.regression.mixed_linear_model.Mix...
# Sphingomyelins                   <statsmodels.regression.mixed_linear_model.Mix...
#
#
#                                 Transformation
# Acylcarnitines                             log
# Amino_Acids_and_Biogenic_Amines            log
# Bile_Acids                                 log
# Ceramides                                  log
# Free_Fatty_Acids                           log
# Free_Oxysterols                            log
# Hexoses                                    log
# Lysophosphatidylcholines                   log
# Phosphatidylcholines                       log
# Phosphatidylethanolamines                  log
# Phosphatidylglycerols                      log
# Phosphatidylserines                        log
# Sphingomyelins                             log

# %%
def plot_param(param='Age[A]:Q("LIscore cent.")', results=results_m4, model='Mixed M4', show_convergence=False):
    fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)
    yticks = np.arange(results.shape[0])
    Estimate = results[('Estimate', param)]
    SE = results[('SE', param)]
    converged = results[('General', 'Converged')]
    convergence_warning_col = 'red' if show_convergence else 'C0'
    color = converged.apply(lambda b: 'C0' if b else convergence_warning_col)
    if show_convergence:
        handles = [mpatches.Patch(color=c) for c in ['C0', 'red']]
        labels = ['yes', 'no']
        fig.legend(handles, labels, title='Converged?', loc='center', bbox_to_anchor=(0.51, 0.85))
    ax[0].barh(yticks, Estimate, xerr=SE, color=color)
    ax[0].set_yticks(yticks)
    ax[0].set_yticklabels(results.index)
    ax[0].set_title('Estimates')
    ax[0].grid(axis='both')
    pval = results[('p', param)]
    ax[1].scatter(x=pval, y=yticks, c=color)
    ax[1].grid(axis='both')
    ax[1].set_title('p-values')
    ax[1].set_xscale('log')
    fig.suptitle(model + ' Parameter: ' + param)
    return((fig, ax))

# %%
#fig, ax = plot_param(param='C(Age, levels=["Y", "A"])[T.A]', results=results_m4, model='Mixed M4')
sel_classes = ['Bile_Acids', 'Free_Oxysterols']
fig, ax = plot_param(param='Age[A]:Q("LIscore cent.")', results=results_m4_log.loc[sel_classes], model='Log-transformed data + mixed M4.', show_convergence=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     151         try:  # Look up in the cache.
# --> 152             return self[type(x)]
#     153         except KeyError:
#
# KeyError: <class 'numpy.ndarray'>
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     151         try:  # Look up in the cache.
# --> 152             return self[type(x)]
#     153         except KeyError:
#
# KeyError: <class 'itertools.chain'>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-cc8beba4e378> in <module>
#       1 #fig, ax = plot_param(param='C(Age, levels=["Y", "A"])[T.A]', results=results_m4, model='Mixed M4')
#       2 sel_classes = ['Bile_Acids', 'Free_Oxysterols']
# ----> 3 fig, ax = plot_param(param='Age[A]:Q("LIscore cent.")', results=results_m4_log.loc[sel_classes], model='Log-transformed data + mixed M4.', show_convergence=False)
#
# <ipython-input-36-16d0776bae55> in plot_param(param, results, model, show_convergence)
#      11         labels = ['yes', 'no']
#      12         fig.legend(handles, labels, title='Converged?', loc='center', bbox_to_anchor=(0.51, 0.85))
# ---> 13     ax[0].barh(yticks, Estimate, xerr=SE, color=color)
#      14     ax[0].set_yticks(yticks)
#      15     ax[0].set_yticklabels(results.index)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2595         kwargs.setdefault('orientation', 'horizontal')
#    2596         patches = self.bar(x=left, height=height, width=width, bottom=y,
# -> 2597                            align=align, **kwargs)
#    2598         return patches
#    2599
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2350                 self.set_yscale('log', nonposy='clip')
#    2351         elif orientation == 'horizontal':
# -> 2352             self._process_unit_info(xdata=width, ydata=y, kwargs=kwargs)
#    2353             if log:
#    2354                 self.set_xscale('log', nonposx='clip')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2121             return kwargs
#    2122
# -> 2123         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
#    2124         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2125         return kwargs
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2104                 # We only need to update if there is nothing set yet.
#    2105                 if not axis.have_units():
# -> 2106                     axis.update_units(data)
#    2107
#    2108             # Check for units in the kwargs, and if present update axis
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axis.py in update_units(self, data)
#    1486         """
#    1487
# -> 1488         converter = munits.registry.get_converter(data)
#    1489         if converter is None:
#    1490             return False
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     160                 # where indexing returns instances of the same iterable class.
#     161                 if type(first) is not type(x):
# --> 162                     return self.get_converter(first)
#     163         return None
#     164
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     153         except KeyError:
#     154             try:  # If cache lookup fails, look up based on first element...
# --> 155                 first = cbook.safe_first_element(x)
#     156             except (TypeError, StopIteration):
#     157                 pass
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in safe_first_element(obj)
#    1660         except TypeError:
#    1661             pass
# -> 1662         raise RuntimeError("matplotlib does not support generators "
#    1663                            "as input")
#    1664     return next(iter(obj))
#
# RuntimeError: matplotlib does not support generators as input
